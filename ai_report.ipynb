# %%
# 设置工作路径为谷歌硬盘
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks")
# Out:
# Mounted at /content/drive

# %%
# 从github上下载yolov5并解压
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# 安装项目依赖
# %pip install -qr requirements.txt

import torch
from IPython.display import Image, clear_output

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else'CPU'))
# Out:
# Setup complete. Using torch 2.9.0+cu126 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15095MB, multi_processor_count=40, uuid=d4a6d1a1-a624-28ab-5d9c-df672fd4d6ae, pci_bus_id=0, pci_device_id=4, pci_domain_id=0, L2_cache_size=4MB)

# %%
# %cd /content/drive/MyDrive/Colab Notebooks
! mkdir ./mask/
! mv mask.zip ./mask/
# %cd ./mask/
! unzip mask.zip
# %cd ../yolov5/
# Out:
# /content
# /content/drive/MyDrive/Colab Notebooks/mask
# Archive:  mask.zip
#  extracting: test/images/1288126-10255706714jpg_jpg.rf.ed230c79fdbb1fa0650ff4fd32f620ee.jpg
#  extracting: test/images/shutterstock_1627199179_jpg.rf.350e69105dd1458572a590c3e3ef2538.jpg
#  extracting: test/images/15391513324714o1n0r10n6_jpg.rf.eb6b6b796ad74b0c9d75011d1020f0af.jpg
#  extracting: train/images/1125506397_15801322206131n_jpg.rf.0a60284a71b2d0ed77c002e768b39b00.jpg
#  extracting: test/images/1579924271_jpg.rf.1fea0f43731fbea2876f63135256004f.jpg
#  extracting: train/images/1_R_kFK9pNLfKAuopY_lAaPQ_jpeg.rf.030922effaedbead963acea666441dbd.jpg
#  extracting: test/images/1224331650_g_400-w_g_jpg.rf.483a35a2395bf48e96783587a59fe876.jpg
#  extracting: train/images/11893820-3x2-xlarge_jpg.rf.1529b09bfee7d069f677ff513f6249eb.jpg
#  extracting: train/images/r1p00017o80q34s9781_jpg.rf.1ef0de5c875f7e73138d8c9f988eb12e.jpg
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 300 --data ../mask/data.yaml --cfg models/yolov5s.yaml --weights ''
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#      37/299      4.18G    0.07411    0.08624    0.01637        211        640:  57% 4/7 [00:01<00:00,  3.13it/s]/content/drive/MyDrive/Colab Notebooks/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#      37/299      4.18G    0.07247    0.08341     0.0155        120        640:  71% 5/7 [00:01<00:00,  2.19it/s]/content/drive/MyDrive/Colab Notebooks/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#      37/299      4.18G    0.07342    0.08274    0.01677        164        640:  86% 6/7 [00:02<00:00,  2.15it/s]/content/drive/MyDrive/Colab Notebooks/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
import yaml
import os

# 1. 确保上级目录存在（防止路径报错）
os.makedirs('../mask', exist_ok=True)

# 2. 定义完全干净的配置内容
data_content = {
    'train': '../mask/train/images',
    'val':   '../mask/valid/images',
    'nc':    2,
    'names': ['mask', 'no-mask']
}

# 3. 覆盖写入到 data.yaml (使用 safe_dump 保证格式标准)
with open('../mask/data.yaml', 'w') as f:
    yaml.safe_dump(data_content, f, sort_keys=False)

print("SUCCESS: data.yaml 已被重写并修复格式问题！")
print("文件内容如下：")
# !cat ../mask/data.yaml
# Out:
# SUCCESS: data.yaml 已被重写并修复格式问题！
# 文件内容如下：
# train: ../mask/train/images
# val: ../mask/valid/images
# nc: 2
# names:
# - mask
# - no-mask

# %%
# 切换到你的 yolov5 文件夹目录下
# %cd /content/drive/MyDrive/Colab\ Notebooks/yolov5

# 安装所有必要的库
# !pip install -r requirements.txt
# Out:
# /content/drive/MyDrive/Colab Notebooks/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 71.9 MB/s eta 0:00:00
# ...

# %%
! python detect.py --weight runs/train/exp4/weights/best.pt --source mask.jpg
# Out:
# detect: weights=['runs/train/exp4/weights/best.pt'], source=mask.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# YOLOv5 🚀 2025-12-24 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/drive/MyDrive/Colab Notebooks/yolov5/mask.jpg: 384x640 1 mask, 2 no-masks, 35.1ms
# Speed: 0.5ms pre-process, 35.1ms inference, 96.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp4

# %%
! python detect.py --weight runs/train/exp7/weights/best.pt --source mask.jpg
# Out:
# detect: weights=['runs/train/exp7/weights/best.pt'], source=mask.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# YOLOv5 🚀 2025-12-24 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
#
# Fusing layers...
# YOLOv5m summary: 212 layers, 20856975 parameters, 0 gradients, 47.9 GFLOPs
# image 1/1 /content/drive/MyDrive/Colab Notebooks/yolov5/mask.jpg: 384x640 1 mask, 2 no-masks, 53.2ms
# Speed: 0.5ms pre-process, 53.2ms inference, 55.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp5
